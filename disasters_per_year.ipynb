# %%
import pandas as pd
from pathlib import Path

# %%
# Create a reference the CSV file desired
csv_path = Path("Filtered_Clean_DataAnalysis_NaturalDisasters_1970-2021.csv")

# Read the CSV into a Pandas DataFrame
disasters_df = pd.read_csv(csv_path, low_memory=False)

# Print the first five rows of data to the screen
disasters_df.head()
# Out:
#    Index  Total Damages  Total Deaths         Dis No Disaster Group  \
# 0      0        25000.0          36.0  1970-0013-ARG        Natural
# 1      3        86400.0      300000.0  1970-0063-BGD        Natural
# 2      4            NaN          17.0  1970-0026-BGD        Natural
# 3      6            NaN         300.0  1970-0058-BGD        Natural
# 4      8        46000.0         172.0  1970-0037-BRA        Natural
#
#   Disaster Subgroup Disaster Type  Disaster Subtype Disaster Subsubtype  \
# 0      Hydrological         Flood               NaN                 NaN
# 1    Meteorological         Storm  Tropical cyclone                 NaN
# 2    Meteorological         Storm               NaN                 NaN
# 3    Meteorological         Storm               NaN                 NaN
# 4      Hydrological         Flood               NaN                 NaN
#
#       Country  ... Start Month Start Day End_Date_Complete_Y_N End Year  \
# ...

# %%
disasters_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11469 entries, 0 to 11468
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Index                              11469 non-null  int64
#  1   Total Damages                      4265 non-null   float64
#  2   Total Deaths                       8501 non-null   float64
#  3   Dis No                             11469 non-null  object
#  4   Disaster Group                     11469 non-null  object
#  5   Disaster Subgroup                  11469 non-null  object
#  6   Disaster Type                      11469 non-null  object
#  7   Disaster Subtype                   9465 non-null   object
#  8   Disaster Subsubtype                966 non-null    object
#  9   Country                            11469 non-null  object
#  10  Region                             11469 non-null  object
# ...

# %%
# Total disasters of each type
disaster_counts = disasters_df["Disaster Type"].value_counts()
disaster_counts
# Out:
# Flood                    4467
# Storm                    3718
# Earthquake               1137
# Epidemic                  657
# Landslide                 646
# Wildfire                  296
# Extreme temperature       294
# Volcanic activity         196
# Mass movement (dry)        37
# Insect infestation          9
# Drought                     8
# Glacial lake outburst       2
# Impact                      1
# Animal accident             1
# Name: Disaster Type, dtype: int64

# %%
disasters_per_year = disasters_df.groupby(["Start Year"])["Disaster Type"].count().reset_index()
disasters_per_year
# Out:
#     Start Year  Disaster Type
# 0         1970             66
# 1         1971             39
# 2         1972             47
# 3         1973             41
# 4         1974             42
# 5         1975             35
# 6         1976             63
# 7         1977             75
# 8         1978             54
# 9         1979             69
# 10        1980             77
# 11        1981             93
# 12        1982             94
# 13        1983            111
# 14        1984             85
# 15        1985            109
# 16        1986            109
# 17        1987            134
# 18        1988            132
# 19        1989            135
# 20        1990            255
# 21        1991            211
# 22        1992            178
# 23        1993            223
# 24        1994            203
# 25        1995            223
# 26        1996            222
# 27        1997            265
# 28        1998            297
# 29        1999            275
# ...

# %%
years = disasters_per_year["Start Year"].tolist()
dis_total = disasters_per_year["Disaster Type"].tolist()

# %%
disasters_per_year_df = pd.DataFrame({"Year": years,
                                      "Total_Disasters": dis_types})
disasters_per_year_df
# Out:
#     Year  Total_Disasters
# 0   1970               66
# 1   1971               39
# 2   1972               47
# 3   1973               41
# 4   1974               42
# 5   1975               35
# 6   1976               63
# 7   1977               75
# 8   1978               54
# 9   1979               69
# 10  1980               77
# 11  1981               93
# 12  1982               94
# 13  1983              111
# 14  1984               85
# 15  1985              109
# 16  1986              109
# 17  1987              134
# 18  1988              132
# 19  1989              135
# 20  1990              255
# 21  1991              211
# 22  1992              178
# 23  1993              223
# 24  1994              203
# 25  1995              223
# 26  1996              222
# 27  1997              265
# 28  1998              297
# 29  1999              275
# 30  2000              338
# 31  2001              334
# 32  2002              406
# 33  2003              364
# ...

# %%
# Export the DataFrame as a CSV file. 
disasters_per_year_df.to_csv("Outputs/disasters_per_year.csv", index=False)
