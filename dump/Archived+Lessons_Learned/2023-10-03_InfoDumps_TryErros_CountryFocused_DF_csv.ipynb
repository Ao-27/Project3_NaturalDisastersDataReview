# %%
# Import dependencies
import pandas as pd
import numpy as np
import os

# %%
# Change directory to the directory of current python script. 
#via URL => https://stackoverflow.com/questions/1432924/python-change-the-scripts-working-directory-to-the-scripts-own-directory
#via URL => https://www.geeksforgeeks.org/python-os-path-abspath-method-with-example/

file_name = "CountryFocused_DF_csv.ipynb"
abs_path = os.path.abspath(file_name)        #(__file__)
print(abs_path)
dir_name = os.path.dirname(abs_path)
print(dir_name)
print("-----")
os.chdir(dir_name)
# Out:
# c:\Users\Aolda\OneDrive\Desktop\SCS_Modules_ToGitHub\Project3_Leaflet\Project3_NaturalDisastersDataReview\CountryFocused_DF_csv.ipynb
# c:\Users\Aolda\OneDrive\Desktop\SCS_Modules_ToGitHub\Project3_Leaflet\Project3_NaturalDisastersDataReview
# -----

# %%
#Confirm VAR for location of Resources Folder.
target_directory_file1 = "Resources/Country_LatLong/"
source1_file_name = "world_country_and_usa_states_latitude_and_longitude_values.csv"

Pandas_read_file1 = target_directory_file1 + source1_file_name

# %%
#Confirm VAR for location of Resources Folder.
target_directory_file2 = "Outputs/"
source2_file_name = "Filtered_Clean_DataAnalysis_NaturalDisasters_1970-2021.csv"

Pandas_read_file2 = target_directory_file2 + source2_file_name

# %%
# Read the data into a Pandas DataFrame. Reminder pd.read_csv() is targeted to current working directory.

Country_lat_long_df = pd.read_csv(Pandas_read_file1) #, index_col=index_col_file1)  #SeeNote1+Error below ... dropping the index assignment for now ...  , usecols=usecols_file1)
Country_lat_long_df.head()
# Out:
#   country_code   latitude  longitude         country
# 0           CZ  49.817492  15.472962  Czech Republic
# 1           DE  51.165691  10.451526         Germany
# 2           DJ  11.825138  42.590275        Djibouti
# 3           DK  56.263920   9.501785         Denmark
# 4           DM  15.414999 -61.370976        Dominica

# %%
# Read the data into a Pandas DataFrame. Reminder pd.read_csv() is targeted to current working directory.

Filtered_Complete_DataAnalysis_df = pd.read_csv(Pandas_read_file2) #, index_col=index_col_file1)  #SeeNote1+Error below ... dropping the index assignment for now ...  , usecols=usecols_file1)
Filtered_Complete_DataAnalysis_df.head()
# Out:
#    Index  Total Damages ('000 US$)  Total Deaths         Dis No  \
# 0      0                   25000.0          36.0  1970-0013-ARG
# 1      3                   86400.0      300000.0  1970-0063-BGD
# 2      4                       NaN          17.0  1970-0026-BGD
# 3      6                       NaN         300.0  1970-0058-BGD
# 4      8                   46000.0         172.0  1970-0037-BRA
#
#   Disaster Group Disaster Subgroup Disaster Type  Disaster Subtype  \
# 0        Natural      Hydrological         Flood               NaN
# 1        Natural    Meteorological         Storm  Tropical cyclone
# 2        Natural    Meteorological         Storm               NaN
# 3        Natural    Meteorological         Storm               NaN
# 4        Natural      Hydrological         Flood               NaN
#
#   Disaster Subsubtype     Country  ... Start Month Start Day  \
# 0                 NaN   Argentina  ...           1         4
# ...

# %%
Filtered_Complete_DataAnalysis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11469 entries, 0 to 11468
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Index                              11469 non-null  int64
#  1   Total Damages ('000 US$)           4265 non-null   float64
#  2   Total Deaths                       8501 non-null   float64
#  3   Dis No                             11469 non-null  object
#  4   Disaster Group                     11469 non-null  object
#  5   Disaster Subgroup                  11469 non-null  object
#  6   Disaster Type                      11469 non-null  object
#  7   Disaster Subtype                   9465 non-null   object
#  8   Disaster Subsubtype                966 non-null    object
#  9   Country                            11469 non-null  object
#  10  Region                             11469 non-null  object
# ...

# %%
#via URL => https://stackoverflow.com/questions/19482970/get-a-list-from-pandas-dataframe-column-headers


List_of_Analysis2_Columns = Filtered_Complete_DataAnalysis_df.columns.values.tolist()

List_of_Analysis2_Columns
# Out:
# ['Index',
#  "Total Damages ('000 US$)",
#  'Total Deaths',
#  'Dis No',
#  'Disaster Group',
#  'Disaster Subgroup',
#  'Disaster Type',
#  'Disaster Subtype',
#  'Disaster Subsubtype',
#  'Country',
#  'Region',
#  'Location',
#  'Continent',
#  'Start_Date_Complete_Y_N',
#  'Start Year',
#  'Start Month',
#  'Start Day',
#  'End_Date_Complete_Y_N',
#  'End Year',
#  'End Month',
#  'End Day',
#  'Start Date',
#  'End Date',
#  'Start to End Date_Duration Days',
#  'Start to End Date_Duration Months']

# %%
#Create unique list of Filtered Data to enable comparatives via str.lower()

#Disaster_groups = pd.Series(Analysis_natural_disasters_df[List_of_Analysis1_Columns[3]].unique().tolist())
#Disaster_subgroups = pd.Series(Analysis_natural_disasters_df[List_of_Analysis1_Columns[4]].unique().tolist())
#Disaster_types = pd.Series(Analysis_natural_disasters_df[List_of_Analysis1_Columns[5]].unique().tolist())
#Disaster_Subtypes = pd.Series(Analysis_natural_disasters_df[List_of_Analysis1_Columns[6]].unique().tolist())
#Disaster_Subsubtypes = pd.Series(Analysis_natural_disasters_df[List_of_Analysis1_Columns[7]].unique().tolist())
Disaster_countries = pd.Series(Filtered_Complete_DataAnalysis_df[List_of_Analysis2_Columns[9]].unique().tolist())
#Disaster_region = pd.Series(Analysis_natural_disasters_df[List_of_Analysis1_Columns[9]].unique().tolist())
#Diasaster_contenent = pd.Series(Analysis_natural_disasters_df[List_of_Analysis1_Columns[11]].unique().tolist())
#Disaster_location = pd.Series(Analysis_natural_disasters_df[List_of_Analysis1_Columns[10]].unique().tolist())

Disaster_countries
# Out:
# 0                       Argentina
# 1                      Bangladesh
# 2                          Brazil
# 3                        Barbados
# 4                          Canada
#                   ...
# 221                         Qatar
# 222              Saint Barthélemy
# 223    Saint Martin (French Part)
# 224     Sint Maarten (Dutch part)
# 225                   Isle of Man
# Length: 226, dtype: object

# %%
List_of_Analysis1_Columns = Country_lat_long_df.columns.values.tolist()

List_of_Analysis1_Columns
# Out:
# ['country_code', 'latitude', 'longitude', 'country']

# %%
#Create series for Lat Long Countries... #Country_lat_long_df

Lat_long_Countries = pd.Series(Country_lat_long_df[List_of_Analysis1_Columns[3]].unique().tolist())

Lat_long_Countries
# Out:
# 0      Czech Republic
# 1             Germany
# 2            Djibouti
# 3             Denmark
# 4            Dominica
#             ...
# 189           Mayotte
# 190      South Africa
# 191            Zambia
# 192          Zimbabwe
# 193            Canada
# Length: 194, dtype: object

# %%
#compare countries using lower() to "fuzzy" assess matches.

Matched_Countries = [i for x in Lat_long_Countries for i in Disaster_countries if i.lower() == x.lower()] #.sort()

Matched_Countries = pd.Series(sorted(Matched_Countries)) #.astype("string")   #VIA URL => https://realpython.com/python-sort/

def get_country(Matched_Countries):
     return Matched_Countries.get()

#Matched_Countries = list(Matched_Countries).sort(key=get_country,reverse=False)

print(Matched_Countries) #.str)   #.str.get(:))
# Out:
# 0                Algeria
# 1               Cambodia
# 2                 Canada
# 3                   Chad
# 4                Croatia
#              ...
# 130              Vanuatu
# 131    Wallis and Futuna
# 132                Yemen
# 133               Zambia
# 134             Zimbabwe
# Length: 135, dtype: object

# %%
#merge by country name. Above confirmed 135 merges will be taking place ... I'll drop na from the merge column ... 

Merged_filtered_wLatLong_df = Country_lat_long_df.merge(Filtered_Complete_DataAnalysis_df.assign(in_index="Found_in_Disasters"),
                                                                      left_on=List_of_Analysis1_Columns[3], right_on=List_of_Analysis2_Columns[9], how='right').fillna({'in_index':'Lost_Filtered_Data'})

Merged_filtered_wLatLong_df.tail(15)
# Out:
#       country_code   latitude  longitude                           country  \
# 11454          NaN        NaN        NaN                               NaN
# 11455          NaN        NaN        NaN                               NaN
# 11456          NaN        NaN        NaN                               NaN
# 11457           UZ  41.377491  64.585262                        Uzbekistan
# 11458           VC  12.984305 -61.287228  Saint Vincent and the Grenadines
# 11459           VC  12.984305 -61.287228  Saint Vincent and the Grenadines
# 11460          NaN        NaN        NaN                               NaN
# 11461          NaN        NaN        NaN                               NaN
# 11462          NaN        NaN        NaN                               NaN
# 11463          NaN        NaN        NaN                               NaN
# 11464           YE  15.552727  48.516388                             Yemen
# ...

# %%
Full_GrpBy_Cols = pd.Series(Merged_filtered_wLatLong_df.columns.values.tolist())

#Note ... I didn't have pd.Series() above ... and probably could have "just" done that ...

#via URL => https://datagy.io/python-zip-lists/
#list_a = Full_GrpBy_Cols.index
#list_b = Full_GrpBy_Cols

#Below ... is my "by hand" attempt without ... finding a URL.
#Full_GrpBy_Cols = set(list(range(len(Full_GrpBy_Cols))),Full_GrpBy_Cols)

#zipped = (list_a, list_b)
#Full_GrpBy_Cols = zipped

Full_GrpBy_Cols
# Out:
# 0                          country_code
# 1                              latitude
# 2                             longitude
# 3                               country
# 4                                 Index
# 5              Total Damages ('000 US$)
# 6                          Total Deaths
# 7                                Dis No
# 8                        Disaster Group
# 9                     Disaster Subgroup
# 10                        Disaster Type
# 11                     Disaster Subtype
# 12                  Disaster Subsubtype
# 13                              Country
# 14                               Region
# 15                             Location
# 16                            Continent
# 17              Start_Date_Complete_Y_N
# 18                           Start Year
# 19                          Start Month
# 20                            Start Day
# 21                End_Date_Complete_Y_N
# 22                             End Year
# ...

# %%
#Reduced_GrpBy_Cols = [[Full_GrpBy_Cols[0],Full_GrpBy_Cols[1],Full_GrpBy_Cols[2],Full_GrpBy_Cols[13],Full_GrpBy_Cols[14],Full_GrpBy_Cols[16],Full_GrpBy_Cols[7],Full_GrpBy_Cols[6],Full_GrpBy_Cols[27],Full_GrpBy_Cols[28],Full_GrpBy_Cols[9],Full_GrpBy_Cols[10],Full_GrpBy_Cols[11],Full_GrpBy_Cols[8]]] #Needed for removal of "NaNs" step .... 

Reduced_merged_df = Merged_filtered_wLatLong_df.loc[ : , [Full_GrpBy_Cols[0],Full_GrpBy_Cols[1],Full_GrpBy_Cols[2],Full_GrpBy_Cols[13],Full_GrpBy_Cols[14],Full_GrpBy_Cols[16],Full_GrpBy_Cols[7],Full_GrpBy_Cols[6],Full_GrpBy_Cols[27],Full_GrpBy_Cols[28],Full_GrpBy_Cols[9],Full_GrpBy_Cols[10],Full_GrpBy_Cols[11],Full_GrpBy_Cols[8]]]
                                                    
                                                    
                                                    # Reduced_GrpBy_Cols] #ERROR ... not working for some reason ... come back to it in the future ... 

Reduced_merged_df.head()
# Out:
#   country_code  latitude  longitude     Country         Region Continent  \
# 0          NaN       NaN        NaN   Argentina  South America  Americas
# 1          NaN       NaN        NaN  Bangladesh  Southern Asia      Asia
# 2          NaN       NaN        NaN  Bangladesh  Southern Asia      Asia
# 3          NaN       NaN        NaN  Bangladesh  Southern Asia      Asia
# 4          NaN       NaN        NaN      Brazil  South America  Americas
#
#           Dis No  Total Deaths Start to End Date_Duration Days  \
# 0  1970-0013-ARG          36.0                          0 days
# 1  1970-0063-BGD      300000.0                          0 days
# 2  1970-0026-BGD          17.0                          0 days
# 3  1970-0058-BGD         300.0                          0 days
# 4  1970-0037-BRA         172.0                          0 days
#
#    Start to End Date_Duration Months Disaster Subgroup Disaster Type  \
# 0                                0.0      Hydrological         Flood
# ...

# %%
Reduced_GrpBy_Cols = pd.Series(Reduced_merged_df.columns.values.tolist())
print(Reduced_GrpBy_Cols)

Reduced_merged_df.info()

fill_na_values = {str(Reduced_GrpBy_Cols[0]):"N/A" ,str(Reduced_GrpBy_Cols[1]):0,str(Reduced_GrpBy_Cols[2]):0}

Analysis_Reduced_merged_df = Reduced_merged_df.fillna(value=fill_na_values)  


#     Pivoting to URL approach => https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html
# Reduced_merged_df.loc[["latitude"] != np.nan , Reduced_GrpBy_Cols ]     # (["latitude"] != "" or ["longitude"] != "") == True , Reduced_GrpBy_Cols ]  # (["latitude"] != "" | ["longitude"] != "") , Reduced_GrpBy_Cols ]

Analysis_Reduced_merged_df.tail(12)
# Out:
# 0                          country_code
# 1                              latitude
# 2                             longitude
# 3                               Country
# 4                                Region
# 5                             Continent
# 6                                Dis No
# 7                          Total Deaths
# 8       Start to End Date_Duration Days
# 9     Start to End Date_Duration Months
# 10                    Disaster Subgroup
# 11                        Disaster Type
# 12                     Disaster Subtype
# 13                       Disaster Group
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11469 entries, 0 to 11468
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   country_code                       5825 non-null   object
#  1   latitude                           5839 non-null   float64
# ...

# %%
Filter_to_Value = 0

#Filtered_Complete_DataAnalysis_toCsv = Complete_DataAnalysis_toCsv.query('Start_Date_Complete_Y_N == @Filter_to_Value and End_Date_Complete_Y_N == @Filter_to_Value ')

#Used URL => https://towardsdatascience.com/use-pandas-query-to-filter-or-select-data-in-pandas-dataframe-82ae3a3683a1

Analysis_Reduced_merged_df2 = Analysis_Reduced_merged_df.query('latitude != @Filter_to_Value' ) # #loc[["latitude"] != 0]

Analysis_Reduced_merged_df2
# Out:
#       country_code   latitude   longitude                           Country  \
# 6               CA  56.130366 -106.346771                            Canada
# 17              DM  15.414999  -61.370976                          Dominica
# 18              EC  -1.831239  -78.183406                           Ecuador
# 19              EC  -1.831239  -78.183406                           Ecuador
# 20              ET   9.145000   40.489673                          Ethiopia
# ...            ...        ...         ...                               ...
# 11459           VC  12.984305  -61.287228  Saint Vincent and the Grenadines
# 11464           YE  15.552727   48.516388                             Yemen
# 11465           YE  15.552727   48.516388                             Yemen
# 11466           ZA -30.559482   22.937506                      South Africa
# 11468           RS  44.016521   21.005859                            Serbia
#
# ...

# %%
print(Reduced_GrpBy_Cols)

Analysis_Reduced_merged_df2.info()
# Out:
# 0                          country_code
# 1                              latitude
# 2                             longitude
# 3                               Country
# 4                                Region
# 5                             Continent
# 6                                Dis No
# 7                          Total Deaths
# 8       Start to End Date_Duration Days
# 9     Start to End Date_Duration Months
# 10                    Disaster Subgroup
# 11                        Disaster Type
# 12                     Disaster Subtype
# 13                       Disaster Group
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5839 entries, 6 to 11468
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   country_code                       5839 non-null   object
#  1   latitude                           5839 non-null   float64
# ...

# %%
fill_na_values = {str(Reduced_GrpBy_Cols[7]):"N/A"} # ,str(Reduced_GrpBy_Cols[1]):0,str(Reduced_GrpBy_Cols[2]):0}

Analysis_Reduced_merged_df3 = Analysis_Reduced_merged_df2.fillna(value=fill_na_values)  

new_name = {
     "Dis No" : "Dis_No",
     "Total Deaths":"Total_Deaths"
}

Analysis_Reduced_merged_df3 = Analysis_Reduced_merged_df3.rename(columns=new_name)

Analysis_Reduced_merged_df3
# Out:
#       country_code   latitude   longitude                           Country  \
# 6               CA  56.130366 -106.346771                            Canada
# 17              DM  15.414999  -61.370976                          Dominica
# 18              EC  -1.831239  -78.183406                           Ecuador
# 19              EC  -1.831239  -78.183406                           Ecuador
# 20              ET   9.145000   40.489673                          Ethiopia
# ...            ...        ...         ...                               ...
# 11459           VC  12.984305  -61.287228  Saint Vincent and the Grenadines
# 11464           YE  15.552727   48.516388                             Yemen
# 11465           YE  15.552727   48.516388                             Yemen
# 11466           ZA -30.559482   22.937506                      South Africa
# 11468           RS  44.016521   21.005859                            Serbia
#
# ...

# %%
Filter_to_Value2 = "N/A"

Analysis_Reduced_merged_df4 = Analysis_Reduced_merged_df3.query(r'Total_Deaths != @Filter_to_Value2')  #' ) # #loc[["latitude"] != 0]

Analysis_Reduced_merged_df4
# Out:
#       country_code   latitude   longitude       Country            Region  \
# 6               CA  56.130366 -106.346771        Canada  Northern America
# 18              EC  -1.831239  -78.183406       Ecuador     South America
# 19              EC  -1.831239  -78.183406       Ecuador     South America
# 20              ET   9.145000   40.489673      Ethiopia    Eastern Africa
# 21              FR  46.227638    2.213749        France    Western Europe
# ...            ...        ...         ...           ...               ...
# 11445           UG   1.373333   32.290275        Uganda    Eastern Africa
# 11457           UZ  41.377491   64.585262    Uzbekistan      Central Asia
# 11464           YE  15.552727   48.516388         Yemen      Western Asia
# 11465           YE  15.552727   48.516388         Yemen      Western Asia
# 11466           ZA -30.559482   22.937506  South Africa   Southern Africa
#
#       Continent         Dis_No Total_Deaths Start to End Date_Duration Days  \
# ...

# %%
Region_GrpBy_Totals = Analysis_Reduced_merged_df4.groupby('Region')[['Country']].count()

#
#HAS ERRORS ... 
#
Region_GrpBy_Totals
# Out:
#                            Country
# Region
# Australia and New Zealand       17
# Caribbean                      160
# Central America                407
# Central Asia                    72
# Eastern Africa                 463
# Eastern Asia                   251
# Eastern Europe                 135
# Melanesia                      115
# Micronesia                       4
# Middle Africa                   32
# Northern Africa                125
# Northern America                38
# Northern Europe                 46
# Polynesia                       21
# South America                  179
# South-Eastern Asia             512
# Southern Africa                 94
# Southern Asia                  792
# Southern Europe                243
# Western Africa                 207
# Western Asia                   243
# Western Europe                 161

# %%
Analysis_Reduced_merged_df4.describe()
# Out:
#           latitude    longitude  Start to End Date_Duration Months
# count  4317.000000  4317.000000                        4314.000000
# mean     17.234385    33.603984                           0.353674
# std      20.400308    72.011813                           1.293374
# min     -40.900557  -177.156097                           0.000000
# 25%      -0.023559     1.659626                           0.000000
# 50%      20.593684    35.529562                           0.032855
# 75%      31.791702    78.962880                           0.197129
# max      64.963051   179.414413                          31.376414

# %%
disasters_per_country = Analysis_Reduced_merged_df4.groupby('Country')['Dis_No'].count().sort_values(ascending=False).reset_index

disasters_per_country
# Out:
# <bound method Series.reset_index of Country
# India                474
# Indonesia            348
# Mexico               196
# Japan                196
# Pakistan             172
#                     ...
# Equatorial Guinea      1
# Grenada                1
# Singapore              1
# Gabon                  1
# Niue                   1
# Name: Dis_No, Length: 128, dtype: int64>

# %%
disaster_types_count = Analysis_Reduced_merged_df4.groupby('Disaster Type').size().sort_values(ascending=False).reset_index()
disaster_types_count.columns = ["Disaster Type","Count"]

disaster_types_count
# Out:
#            Disaster Type  Count
# 0                  Flood   1826
# 1                  Storm   1119
# 2             Earthquake    440
# 3              Landslide    354
# 4               Epidemic    310
# 5   Extreme temperature     152
# 6               Wildfire     60
# 7      Volcanic activity     35
# 8    Mass movement (dry)     19
# 9  Glacial lake outburst      2

# %%
Disaster_Types_by_Country_no = Analysis_Reduced_merged_df4.groupby('Country').count()


#Analysis_Reduced_merged_df4.groupby('Disaster Type')['Country'].size().sort_values(ascending=False).reset_index()

Disaster_Types_by_Country_no
# Out:
#                    country_code  latitude  longitude  Region  Continent  \
# Country
# Algeria                      56        56         56      56         56
# Cambodia                     23        23         23      23         23
# Canada                       38        38         38      38         38
# Chad                         30        30         30      30         30
# Croatia                       7         7          7       7          7
# ...                         ...       ...        ...     ...        ...
# Vanuatu                      13        13         13      13         13
# Wallis and Futuna             2         2          2       2          2
# Yemen                        49        49         49      49         49
# Zambia                       15        15         15      15         15
# Zimbabwe                     24        24         24      24         24
#
#                    Dis_No  Total_Deaths  Start to End Date_Duration Days  \
# Country
# ...

# %%
Disaster_Types_by_Country_no2 = Analysis_Reduced_merged_df4.groupby('Country').size()

Disaster_Types_by_Country_no2
# Out:
# Country
# Algeria              56
# Cambodia             23
# Canada               38
# Chad                 30
# Croatia               7
#                      ..
# Vanuatu              13
# Wallis and Futuna     2
# Yemen                49
# Zambia               15
# Zimbabwe             24
# Length: 128, dtype: int64

# %%
Disaster_types_Unique = pd.Series(disaster_types_count['Disaster Type'].tolist())

Disaster_types_Unique
# Out:
# 0                    Flood
# 1                    Storm
# 2               Earthquake
# 3                Landslide
# 4                 Epidemic
# 5     Extreme temperature
# 6                 Wildfire
# 7        Volcanic activity
# 8      Mass movement (dry)
# 9    Glacial lake outburst
# dtype: object

# %%
df_group0 = Analysis_Reduced_merged_df4.groupby('Country')

row_list = []
for name,group in df_group0:
     RecordtoAdd = {}
     RecordtoAdd.update({'Country':name})
     if group['Disaster Type'] == True:# = "Disaster Type":
          RecordtoAdd.update({'Type of Occurence':group['Disaster Type']})
          RecordtoAdd.update({'List of Unique':pd.unique(group['Disaster Type'])})
          RecordtoAdd.update({'Num of Unique Types':len(pd.unique(group['Disaster Type']))})
     row_list.append(RecordtoAdd)

AnalysisData = pd.DataFrame(row_list)

print(AnalysisData)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Aolda\OneDrive\Desktop\SCS_Modules_ToGitHub\Project3_Leaflet\Project3_NaturalDisastersDataReview\CountryFocused_DF_csv.ipynb Cell 28 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/Aolda/OneDrive/Desktop/SCS_Modules_ToGitHub/Project3_Leaflet/Project3_NaturalDisastersDataReview/CountryFocused_DF_csv.ipynb#X62sZmlsZQ%3D%3D?line=4'>5</a> RecordtoAdd = {}
#       <a href='vscode-notebook-cell:/c%3A/Users/Aolda/OneDrive/Desktop/SCS_Modules_ToGitHub/Project3_Leaflet/Project3_NaturalDisastersDataReview/CountryFocused_DF_csv.ipynb#X62sZmlsZQ%3D%3D?line=5'>6</a> RecordtoAdd.update({'Country':name})
# ...

# %%
df_group = Analysis_Reduced_merged_df4.groupby('Disaster Type') # Analysis_Reduced_merged_df4.groupby('Country')
floods_only_df = df_group.get_group(Disaster_types_Unique[0])     #.get_group(['Disaster Type']) # == Disaster_types_Unique[0])
Storm_only_df = df_group.get_group(Disaster_types_Unique[1])
Earthquake_only_df = df_group.get_group(Disaster_types_Unique[2]) 
Landslide_only_df = df_group.get_group(Disaster_types_Unique[3]) 
Epidemic = df_group.get_group(Disaster_types_Unique[4]) 
Extrm_temp_df = df_group.get_group(Disaster_types_Unique[5]) 
WildFire_df = df_group.get_group(Disaster_types_Unique[6]) 
volcano_df = df_group.get_group(Disaster_types_Unique[7]) 
massmovement_df = df_group.get_group(Disaster_types_Unique[8]) 
glacial_df = df_group.get_group(Disaster_types_Unique[9])

# %%
from collections import Counter

# %%
print(disaster_types_count)
print("========")
floods_only_df.head()

flood_countries = pd.Series(floods_only_df.groupby('Country')['Dis_No'].count().sort_values(ascending=False))   #.reset_index)

#Floods_dict = {k:v for (k,v) in (Counter(flood_countries).keys(), Counter(flood_countries).values())}

Floods_Count = zip(Counter(flood_countries).keys(), Counter(flood_countries).values())

print(flood_countries)
print(Floods_Count)

#Complete_DataAnalysis_toCsv.to_csv(output1_file_name)
#flood_countries.to_csv("Flood_Countries_Summary.csv")
#floods_only_df.to_csv("FLoods_only_data.csv")

#Analysis_Reduced_merged_df4.groupby('Country')['Dis_No'].count().sort_values(ascending=False).reset_index
# Out:
#            Disaster Type  Count
# 0                  Flood   1826
# 1                  Storm   1119
# 2             Earthquake    440
# 3              Landslide    354
# 4               Epidemic    310
# 5   Extreme temperature     152
# 6               Wildfire     60
# 7      Volcanic activity     35
# 8    Mass movement (dry)     19
# 9  Glacial lake outburst      2
# ...
# Country
# India         208
# Indonesia     172
# Pakistan       84
# Thailand       58
# Mexico         56
#              ...
# Seychelles      1
# Sweden          1
# Swaziland       1
# Lithuania       1
# Slovenia        1
# Name: Dis_No, Length: 99, dtype: int64
# ...

# %%
print(disaster_types_count)
print("========")
Storm_only_df
# Out:
#            Disaster Type  Count
# 0                  Flood   1826
# 1                  Storm   1119
# 2             Earthquake    440
# 3              Landslide    354
# 4               Epidemic    310
# 5   Extreme temperature     152
# 6               Wildfire     60
# 7      Volcanic activity     35
# 8    Mass movement (dry)     19
# 9  Glacial lake outburst      2
# ...
#       country_code   latitude   longitude       Country              Region  \
# 6               CA  56.130366 -106.346771        Canada    Northern America
# 40              HK  22.396428  114.109497     Hong Kong        Eastern Asia
# 42              IN  20.593684   78.962880         India       Southern Asia
# 43              IN  20.593684   78.962880         India       Southern Asia
# 50              FJ -16.578193  179.414413          Fiji           Melanesia
# ...            ...        ...         ...           ...                 ...
# ...

# %%
for name_of_group,contents_of_group in df_group:
     print(name_of_group)
     print(contents_of_group)
# Out:
# Earthquake
#       country_code   latitude   longitude     Country              Region  \
# 18              EC  -1.831239  -78.183406     Ecuador       South America
# 27              IN  20.593684   78.962880       India       Southern Asia
# 100             IN  20.593684   78.962880       India       Southern Asia
# 118             EC  -1.831239  -78.183406     Ecuador       South America
# 119             EC  -1.831239  -78.183406     Ecuador       South America
# ...            ...        ...         ...         ...                 ...
# 11249           ID  -0.789275  113.921327   Indonesia  South-Eastern Asia
# 11257           IN  20.593684   78.962880       India       Southern Asia
# 11269           JP  36.204824  138.252924       Japan        Eastern Asia
# 11301           PK  30.375321   69.345116    Pakistan       Southern Asia
# 11324           TJ  38.861034   71.276093  Tajikistan        Central Asia
#
# ...

# %%
list_placeholder = []
list_placeholder2 = []
list_placeholder3 = []
for name_of_group,contents_of_group in df_group:
     Name_of_Contents_Dict = {}
     Name_of_Contents_Dict.update({name_of_group:[contents_of_group]})
     Name_of_Grp_Dict = {"grouped_data":Name_of_Contents_Dict}
     list_placeholder.append(Name_of_Grp_Dict)
     #for count,content in  enumerate(contents_of_group,1):
          #Name_of_Contents_Dict = {}
          #Name_of_Grp_Dict = {name_of_group:Name_of_Contents_Dict}
          #list_placeholder2.append(Name_of_Grp_Dict)
          #Name_of_Contents_Dict.update({count:contents_of_group})
          #list_placeholder3.append(Name_of_Contents_Dict)
          #list_placeholder.append(Name_of_Grp_Dict)
     
print(list_placeholder)
     #print(name_of_group)
     #print(contents_of_group)


     #via URL => https://stackoverflow.com/questions/54900315/write-output-from-for-loop-to-a-csv-in-python


    # name_of_grp_list = []
    # name_of_grp_list.append(name_of_group)
    # contents_of_grp_list = []
    # contents_of_grp_list.append(contents_of_group)
    # Analysis_Dict = {}
    # Analysis_Dict.update({name_of_grp_list.pop()[0]:contents_of_grp_list.pop()[0]})
    # print(Analysis_Dict)


#url1 => https://stackoverflow.com/questions/8322534/typeerror-builtin-function-or-method-object-is-not-subscriptable
#url2 => https://stackoverflow.com/questions/44214799/attributeerror-str-object-has-no-attribute-pop

     #name_of_grp_list = []
     #name_of_grp_list.append[name_of_group.split(",").pop()[0]]
     #contents_dict = {}
     #contents_dict.update({name_of_group.pop()[0]:contents_of_group.pop()[0]})
     #name_of_grp_list.append(contents_dict)
     #print(name_of_grp_list)
     #GroupBy_Disasters_Dict = {}
     #Group_Contents_Dict = {}
     #GroupBy_Disasters_Dict.update({name_of_group:contents_of_group}) ##WORKS...
     #GroupBy_Disasters_Dict.update({name_of_group:Group_Contents_Dict})
     #if name_of_group != np.nan:
     #     for k,[v] in contents_of_group:
     #          Group_Contents_Dict.update({str(k):str(v)})
     #GroupBy_Disasters_Dict.update({name_of_group:Group_Contents_Dict})
     #print(name_of_group)
     #print(contents_of_group)
     #print(GroupBy_Disasters_Dict)
     #name_group_dict = {}
     #contents_group_dict = {}
     #name_group_dict.update({str(df_group["Country"]):name_of_group})
     #name_group_dict.update({str(df_group["Disaster Type"]):contents_of_group})

#list_placeholder.append([name_group_dict])
#list_placeholder.append([contents_group_dict])

#New_DF = pd.DataFrame(list_placeholder)
#New_DF
# Out:
# [{'grouped_data': {'Earthquake': [      country_code   latitude   longitude     Country              Region  \
# 18              EC  -1.831239  -78.183406     Ecuador       South America
# 27              IN  20.593684   78.962880       India       Southern Asia
# 100             IN  20.593684   78.962880       India       Southern Asia
# 118             EC  -1.831239  -78.183406     Ecuador       South America
# 119             EC  -1.831239  -78.183406     Ecuador       South America
# ...            ...        ...         ...         ...                 ...
# 11249           ID  -0.789275  113.921327   Indonesia  South-Eastern Asia
# 11257           IN  20.593684   78.962880       India       Southern Asia
# 11269           JP  36.204824  138.252924       Japan        Eastern Asia
# 11301           PK  30.375321   69.345116    Pakistan       Southern Asia
# 11324           TJ  38.861034   71.276093  Tajikistan        Central Asia
#
# ...

# %%
df =  pd.json_normalize(list_placeholder)  #pd.DataFrame(list_placeholder) #.from_dict(list_placeholder, orient='columns')

df
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File c:\Users\Aolda\anaconda3\envs\dev\Lib\site-packages\IPython\core\formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File c:\Users\Aolda\anaconda3\envs\dev\Lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
# ...

# %%
df2 = pd.DataFrame(list_placeholder)

df2
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File c:\Users\Aolda\anaconda3\envs\dev\Lib\site-packages\IPython\core\formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File c:\Users\Aolda\anaconda3\envs\dev\Lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
# ...

# %%
#end_y = Disaster_starting_dates_df['Start Year']
#end_m = Disaster_starting_dates_df['Start Month']
#end_d = Disaster_starting_dates_df['Start Day']
#end_total = Disaster_starting_dates_df['Dis No']
#print(st_d)

#end_y = end_y.isnull().sum()
#end_m = end_m.isnull().sum()
#end_d = end_d.isnull().sum()
#end_total = end_total.count()
#print(end_total)
#print(end_y)
#print(end_m)
#print(end_d)
#print("+-+-+-+-+-+")
#end_y_missing = round( end_y / end_total * 100 , 2)
#end_m_missing = round( end_m / end_total * 100 , 2)
#end_d_missing = round( end_d / end_total * 100 , 2)

#print(f"The End Day column has {end_d_missing} % of missing data.\nThe End Month column has {end_m_missing} % of missing data.\nThe End Year column has {end_y_missing} % of missing data.\n")

# %%
#Merged_filtered_wLatLong_df.info()

# %%
#LatLong_Merged_toCSV = Merged_filtered_wLatLong_df.dropna()

#LatLong_Merged_toCSV

# %%
#Confirm to Disaster starting/ending dates df's the missing data rows via 1s and 0s.
#via URL => https://stackoverflow.com/questions/60094213/for-loop-to-find-rows-in-another-dataframe
#Supporting URL => https://stackoverflow.com/questions/50449088/check-if-value-from-one-dataframe-exists-in-another-dataframe

#Excellent way to create a "custom" boolean for our data cleansing purposes ... with regards to missing data.

#Merged_disaster_starting_dates_df = Disaster_dates_df.merge(Starting_missing_dates.assign(in_index="Missing_Month_or_Day"),
#                                                                      left_on='Dis No', right_on='Dis No', how='left').fillna({'in_index':'Date_Complete'})
#Analysis_disaster_starting_dates_df.info()

#Merged_disaster_starting_dates_df

# %%
#Filter_to_Value = "Date_Complete"

#Filtered_Complete_DataAnalysis_toCsv = Complete_DataAnalysis_toCsv.query('Start_Date_Complete_Y_N == @Filter_to_Value and End_Date_Complete_Y_N == @Filter_to_Value ')

#Used URL => https://towardsdatascience.com/use-pandas-query-to-filter-or-select-data-in-pandas-dataframe-82ae3a3683a1

# %%
#end_y = Disaster_starting_dates_df['Start Year']
#end_m = Disaster_starting_dates_df['Start Month']
#end_d = Disaster_starting_dates_df['Start Day']
#end_total = Disaster_starting_dates_df['Dis No']
#print(st_d)

#end_y = end_y.isnull().sum()
#end_m = end_m.isnull().sum()
#end_d = end_d.isnull().sum()
#end_total = end_total.count()
#print(end_total)
#print(end_y)
#print(end_m)
#print(end_d)
#print("+-+-+-+-+-+")
#end_y_missing = round( end_y / end_total * 100 , 2)
#end_m_missing = round( end_m / end_total * 100 , 2)
#end_d_missing = round( end_d / end_total * 100 , 2)

#print(f"The End Day column has {end_d_missing} % of missing data.\nThe End Month column has {end_m_missing} % of missing data.\nThe End Year column has {end_y_missing} % of missing data.\n")
